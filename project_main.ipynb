# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# ### Functions

# %%
#checking for null values
def check_null():
    columns = list(df.columns)
    for x in columns:
        print(f"The amount nulls in {x} is {df[x].isnull().sum()}")
        
        
        
#checking for unique categorys
def check_unique():
    columns = list(df.columns)
    for x in columns:
        print(f"The different categories of {x} are {df[x].unique()}")        

        
#checkint for the Number of unique categorys
def check_nunique():
    columns = list(df.columns)
    for x in columns:
        print(f"The different categories of {x} are {df[x].nunique()}")  

        
        

#dropping the index (resetting)
def reset_index(table):
    table.reset_index(drop = True, inplace = True)
    
    
    

#dropping Null values
def dropping_null(table):
    print(table.columns)
    Column = input("Please enter the name of the collumn you want clear")
    table.dropna(subset = Column, inplace = True)
    
    reset_index(table)
    print(table[Column].isnull().sum())

    
    
    
    
#dropping columns
def dropping_collumns(table):
    columns = list(table.columns)
    want_continue = True
    
    
    while want_continue == True:
        print(f"Left columns are {list(table.columns)}")
        ask = input("Drop ANOTHER Column?")
        
        if ask == "yes":
            Column = input("Please enter the NAME of the collumn you want drop")
            table.drop(Column, axis=1, inplace=True)
            reset_index(table)
        else:
            
            print(f"Left columns are {list(table.columns)}")
            want_continue = False
            
            
#renaming COLUMNS
def rename_column(table):
    want_continue = True
    
    while want_continue == True:
    
    
        print(list(table.columns))
        print("")
        to_be_renamed = input("Please enter the column you want to RENAME: ")
        new_name = input("Please enter the NEW NAME: ")


        table.rename(columns={to_be_renamed: new_name}, inplace=True)
        if input("Do you want to CONTINUE?: ") == "no".strip():
            want_continue = False
            
#lowering a whole column (hello world)
def lower_column(row):
    return row.lower()

#uppering a whole column (HELLO WORLD)
def upper_column(row):
    return row.upper()

#titling a whole column (Hello World)
def title_column(row):
    return row.title()

#capitalizing a whole column (Hello world)
def title_column(row):
    return row.capitalize()

# %% [markdown]
# # **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 7 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {'ironhack' : 10828,
           'app-academy' : 10525,
           'springboard' : 11035,
           'le-wagon' : 10868,
           'udacity' : 11118,
           'designlab' : 10697}

import re
import pandas as pd
from pandas import json_normalize
import requests



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])

    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school)) 
    
comments = pd.concat(comments)
# Out:
# ironhack
# app-academy
# springboard
# le-wagon
# udacity
# designlab

# %%
comments
# Out:
#          id          name  anonymous hostProgramName  graduatingYear isAlumni  \
# 0    306068     Anonymous       True            None          2023.0    False
# 1    305297   Utku Cikmaz      False            None          2023.0    False
# 2    305278  Nirmal Hodge      False            None          2023.0    False
# 3    305231     Anonymous       True            None          2023.0    False
# 4    305096     Anonymous       True            None          2023.0     True
# ..      ...           ...        ...             ...             ...      ...
# 916  235867     Anonymous      False            None          2015.0     True
# 917  235847     Anonymous      False            None             NaN    False
# 918  235846         Corey      False    UX/UI Design          2015.0     True
# 919  235845        Victor      False            None             NaN    False
# 920  235803      Jonathan      False            None          2014.0     True
#
#                      jobTitle  \
# ...

# %% [markdown]
# #### Notes
# * Primary Key = ID

# %%
from pandas import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])

    website = data['content']['webaddr']
    description = data['content']['description'].strip()
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school


    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)

    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# app-academy
# springboard
# le-wagon
# udacity
# designlab

# %%
locations_list[0]
# Out:
#       id               description  country.id   country.name country.abbrev  \
# 0  15901           Berlin, Germany        57.0        Germany             DE
# 1  16022       Mexico City, Mexico        29.0         Mexico             MX
# 2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
# 3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
# 4  16109             Paris, France        38.0         France             FR
# 5  16375  Miami, FL, United States         1.0  United States             US
# 6  16376             Madrid, Spain        12.0          Spain             ES
# 7  16377          Barcelona, Spain        12.0          Spain             ES
# 8  16709          Lisbon, Portugal        28.0       Portugal             PT
# 9  17233                    Online         NaN            NaN            NaN
#
#    city.id    city.name city.keyword  state.id state.name state.abbrev  \
# ...

# %%
locations = pd.concat(locations_list)
locations
# Out:
#        id                       description  country.id          country.name  \
# 0   15901                   Berlin, Germany        57.0               Germany
# 1   16022               Mexico City, Mexico        29.0                Mexico
# 2   16086            Amsterdam, Netherlands        59.0           Netherlands
# 3   16088                 Sao Paulo, Brazil        42.0                Brazil
# 4   16109                     Paris, France        38.0                France
# 5   16375          Miami, FL, United States         1.0         United States
# 6   16376                     Madrid, Spain        12.0                 Spain
# 7   16377                  Barcelona, Spain        12.0                 Spain
# 8   16709                  Lisbon, Portugal        28.0              Portugal
# 9   17233                            Online         NaN                   NaN
# 0   15704  San Francisco, CA, United States         1.0         United States
# ...

# %%
courses = pd.concat(courses_list)
courses
# Out:
#                      courses     school  school_id
# 0    Cyber Security Bootcamp   ironhack      10828
# 1    Cybersecurity Part-Time   ironhack      10828
# 2    Data Analytics Bootcamp   ironhack      10828
# 3   Data Analytics Part-Time   ironhack      10828
# 4      UX/UI Design Bootcamp   ironhack      10828
# ..                       ...        ...        ...
# 1                  UI Design  designlab      10697
# 2                 UX Academy  designlab      10697
# 3     UX Academy Foundations  designlab      10697
# 4     UX Research & Strategy  designlab      10697
# 5     UX: Interaction Design  designlab      10697
#
# [75 rows x 3 columns]

# %%
badges = pd.concat(badges_list)
badges.head()
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 0          <p>School offers fully online courses</p>  app-academy      10525
# 1  <p>School offers part-time and evening classes...  app-academy      10525

# %%
# any data cleaning still missing here? take a look at the description
schools = pd.concat(schools_list)
schools.head()
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0  www.springboard.com/?utm_source=switchup&utm_m...
# 0                                    www.lewagon.com
# 0  www.udacity.com/?utm_source=switchup&utm_mediu...
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>Founded in 2012, ...
# 0  <span class="truncatable"><p>Springboard is an...
# 0  <span class="truncatable"><p>Le Wagon is a glo...
# 0  <span class="truncatable"><p>Udacity is the tr...
#
#                                              LogoUrl       school  school_id
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...     ironhack      10828
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  app-academy      10525
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  springboard      11035
# ...

# %% [markdown]
# # WORK

# %% [markdown]
# Name of the tables:
# 1. comments
# 2. locations
# 3. courses
# 4. schools
# 5. badges

# %% [markdown]
# #### Checking all the columns

# %%
list(comments.columns)
# Out:
# ['id',
#  'name',
#  'anonymous',
#  'hostProgramName',
#  'graduatingYear',
#  'isAlumni',
#  'jobTitle',
#  'tagline',
#  'body',
#  'rawBody',
#  'createdAt',
#  'queryDate',
#  'program',
#  'user',
#  'overallScore',
#  'comments',
#  'overall',
#  'curriculum',
#  'jobSupport',
#  'review_body',
#  'school']

# %%
list(locations.columns)
# Out:
# ['id',
#  'description',
#  'country.id',
#  'country.name',
#  'country.abbrev',
#  'city.id',
#  'city.name',
#  'city.keyword',
#  'state.id',
#  'state.name',
#  'state.abbrev',
#  'state.keyword',
#  'school',
#  'school_id']

# %%
list(courses.columns)
# Out:
# ['courses', 'school', 'school_id']

# %%
list(schools.columns)
# Out:
# ['website', 'description', 'LogoUrl', 'school', 'school_id']

# %%
list(badges.columns)
# Out:
# ['name', 'keyword', 'description', 'school', 'school_id']

# %% [markdown]
# #### Checking for possible connections between tables

# %%
comments.head()
# Out:
#        id          name  anonymous hostProgramName  graduatingYear isAlumni  \
# 0  306068     Anonymous       True            None          2023.0    False
# 1  305297   Utku Cikmaz      False            None          2023.0    False
# 2  305278  Nirmal Hodge      False            None          2023.0    False
# 3  305231     Anonymous       True            None          2023.0    False
# 4  305096     Anonymous       True            None          2023.0     True
#
#                    jobTitle  \
# 0    Full stack development
# 1  Full Stack Web Developer
# 2          Product Designer
# 3
# 4           Web Development
#
#                                              tagline  \
# 0                                    Now I can do it
# 1                                        It was good
# 2                            Ironhack 100% Worth It!
# 3                             Still waiting a refund
# 4  Transformative Learning Experience - A Review ...
#
# ...

# %%
locations.head()
# Out:
#       id             description  country.id country.name country.abbrev  \
# 0  15901         Berlin, Germany        57.0      Germany             DE
# 1  16022     Mexico City, Mexico        29.0       Mexico             MX
# 2  16086  Amsterdam, Netherlands        59.0  Netherlands             NL
# 3  16088       Sao Paulo, Brazil        42.0       Brazil             BR
# 4  16109           Paris, France        38.0       France             FR
#
#    city.id    city.name city.keyword  state.id state.name state.abbrev  \
# 0  31156.0       Berlin       berlin       NaN        NaN          NaN
# 1  31175.0  Mexico City  mexico-city       NaN        NaN          NaN
# 2  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
# 3  31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
# 4  31136.0        Paris        paris       NaN        NaN          NaN
#
#   state.keyword    school  school_id
# 0           NaN  ironhack      10828
# ...

# %% [markdown]
# #### Dropping columns

# %%
dropping_collumns()
# Out:
# Left columns are ['comment_id', 'anonymous', 'host_program_name', 'graduating_year', 'is_alumni', 'job_title', 'tagline', 'body', 'rawBody', 'createdAt', 'queryDate', 'program', 'user', 'overallScore', 'comments', 'overall', 'curriculum', 'jobSupport', 'review_body', 'school']
# Drop ANOTHER Column?yes
# Please enter the NAME of the collumn you want drophost_program_name
# Left columns are ['comment_id', 'anonymous', 'graduating_year', 'is_alumni', 'job_title', 'tagline', 'body', 'rawBody', 'createdAt', 'queryDate', 'program', 'user', 'overallScore', 'comments', 'overall', 'curriculum', 'jobSupport', 'review_body', 'school']
# Drop ANOTHER Column?yes
# Please enter the NAME of the collumn you want dropis_alumni
# Left columns are ['comment_id', 'anonymous', 'graduating_year', 'job_title', 'tagline', 'body', 'rawBody', 'createdAt', 'queryDate', 'program', 'user', 'overallScore', 'comments', 'overall', 'curriculum', 'jobSupport', 'review_body', 'school']
# Drop ANOTHER Column?yes
# ...

# %%
locations
# Out:
#        id                       description  country.id          country.name  \
# 0   15901                   Berlin, Germany        57.0               Germany
# 1   16022               Mexico City, Mexico        29.0                Mexico
# 2   16086            Amsterdam, Netherlands        59.0           Netherlands
# 3   16088                 Sao Paulo, Brazil        42.0                Brazil
# 4   16109                     Paris, France        38.0                France
# 5   16375          Miami, FL, United States         1.0         United States
# 6   16376                     Madrid, Spain        12.0                 Spain
# 7   16377                  Barcelona, Spain        12.0                 Spain
# 8   16709                  Lisbon, Portugal        28.0              Portugal
# 9   17233                            Online         NaN                   NaN
# 0   15704  San Francisco, CA, United States         1.0         United States
# ...

# %%
comments.head(3)
# Out:
#        id          name  anonymous hostProgramName  graduatingYear isAlumni  \
# 0  306068     Anonymous       True            None          2023.0    False
# 1  305297   Utku Cikmaz      False            None          2023.0    False
# 2  305278  Nirmal Hodge      False            None          2023.0    False
#
#                    jobTitle                  tagline  \
# 0    Full stack development          Now I can do it
# 1  Full Stack Web Developer              It was good
# 2          Product Designer  Ironhack 100% Worth It!
#
#                                                 body  \
# 0  <span class="truncatable"><p></p><p>7 months a...
# 1  <span class="truncatable"><p></p><p>The course...
# 2  <span class="truncatable"><p></p><p>I joined t...
#
#                                              rawBody  ...   queryDate  \
# 0  <p>7 months ago, I only had an idea about html...  ...  2023-10-31
# 1  <p>The course was great. Especially, Luis is a...  ...  2023-10-02
# ...

# %%
dropping_collumns()
# Out:
# Left columns are ['id', 'description', 'country.id', 'country.name', 'country.abbrev', 'city.id', 'city.name', 'city.keyword', 'state.id', 'state.name', 'state.abbrev', 'state.keyword', 'school', 'school_id']
# Drop ANOTHER Column?yes
# Please enter the NAME of the collumn you want dropdescription
# Left columns are ['id', 'country.id', 'country.name', 'country.abbrev', 'city.id', 'city.name', 'city.keyword', 'state.id', 'state.name', 'state.abbrev', 'state.keyword', 'school', 'school_id']
# Drop ANOTHER Column?yes
# Please enter the NAME of the collumn you want dropcity.keyword
# Left columns are ['id', 'country.id', 'country.name', 'country.abbrev', 'city.id', 'city.name', 'state.id', 'state.name', 'state.abbrev', 'state.keyword', 'school', 'school_id']
# Drop ANOTHER Column?yes
# Please enter the NAME of the collumn you want dropstate.id
# ...

# %%
comments.head(5)
# Out:
#        id  anonymous  graduatingYear  \
# 0  306068       True          2023.0
# 1  305297      False          2023.0
# 2  305278      False          2023.0
# 3  305231       True          2023.0
# 4  305096       True          2023.0
#
#                                              tagline   createdAt  \
# 0                                    Now I can do it  10/31/2023
# 1                                        It was good   10/2/2023
# 2                            Ironhack 100% Worth It!   9/30/2023
# 3                             Still waiting a refund   9/28/2023
# 4  Transformative Learning Experience - A Review ...   9/22/2023
#
#                      program overallScore overall curriculum jobSupport  \
# 0                       None          5.0     5.0        5.0        5.0
# 1   Web Development Bootcamp          4.0     5.0        3.0        4.0
# 2      UX/UI Design Bootcamp          5.0     5.0        5.0        5.0
# ...

# %%
schools.head(3)
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0  www.springboard.com/?utm_source=switchup&utm_m...
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>Founded in 2012, ...
# 0  <span class="truncatable"><p>Springboard is an...
#
#                                              LogoUrl       school  school_id
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...     ironhack      10828
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  app-academy      10525
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  springboard      11035

# %%
schools.drop("description", axis=1, inplace=True)

# %%
schools.drop("LogoUrl", axis=1, inplace=True)

# %%
schools.reset_index(drop = True, inplace = True)

# %%
schools
# Out:
#                                              website       school  school_id
# 0                                www.ironhack.com/en     ironhack      10828
# 1                                      appacademy.io  app-academy      10525
# 2  www.springboard.com/?utm_source=switchup&utm_m...  springboard      11035
# 3                                    www.lewagon.com     le-wagon      10868
# 4  www.udacity.com/?utm_source=switchup&utm_mediu...      udacity      11118
# 5                                      designlab.com    designlab      10697

# %%
badges.head()
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 0          <p>School offers fully online courses</p>  app-academy      10525
# 1  <p>School offers part-time and evening classes...  app-academy      10525

# %%
badges.drop("description", axis = 1, inplace = True)
badges.reset_index(drop = True, inplace = True)

# %%
badges.head()
# Out:
#                 name            keyword       school  school_id
# 0   Available Online   available_online     ironhack      10828
# 1  Verified Outcomes  verified_outcomes     ironhack      10828
# 2   Flexible Classes   flexible_classes     ironhack      10828
# 3   Available Online   available_online  app-academy      10525
# 4   Flexible Classes   flexible_classes  app-academy      10525

# %% [markdown]
# #### Renaming columns

# %%
#renaming comments
rename_column()
# Out:
# ['comment_id', 'anonymous', 'graduating_year', 'job_title', 'tagline', 'createdAt', 'program', 'overallScore', 'overall', 'curriculum', 'jobSupport', 'school']
#
# Please enter the column you want to RENAME: createdAt
# Please enter the NEW NAME: created_at
# Do you want to CONTINUE?: yes
# ['comment_id', 'anonymous', 'graduating_year', 'job_title', 'tagline', 'created_at', 'program', 'overallScore', 'overall', 'curriculum', 'jobSupport', 'school']
#
# Please enter the column you want to RENAME: overallScore
# Please enter the NEW NAME: overall_score
# Do you want to CONTINUE?: yes
# ['comment_id', 'anonymous', 'graduating_year', 'job_title', 'tagline', 'created_at', 'program', 'overall_score', 'overall', 'curriculum', 'jobSupport', 'school']
#
# Please enter the column you want to RENAME: jobSupport
# Please enter the NEW NAME: job_support
# Do you want to CONTINUE?: no

# %%
#renaming locations
rename_column(locations)
# Out:
# ['id', 'country.id', 'country.name', 'country.abbrev', 'city.id', 'city.name', 'school', 'school_id']
#
# Please enter the column you want to RENAME: id
# Please enter the NEW NAME: campus_id
# Do you want to CONTINUE?: yes
# ['campus_id', 'country.id', 'country.name', 'country.abbrev', 'city.id', 'city.name', 'school', 'school_id']
#
# Please enter the column you want to RENAME: country.id
# Please enter the NEW NAME: country_id
# Do you want to CONTINUE?: yes
# ['campus_id', 'country_id', 'country.name', 'country.abbrev', 'city.id', 'city.name', 'school', 'school_id']
#
# Please enter the column you want to RENAME: country.name
# Please enter the NEW NAME: country_name
# Do you want to CONTINUE?: yes
# ['campus_id', 'country_id', 'country_name', 'country.abbrev', 'city.id', 'city.name', 'school', 'school_id']
#
# Please enter the column you want to RENAME: country.abbrev
# Please enter the NEW NAME: country_abbrev
# Do you want to CONTINUE?: yes
# ...

# %%
#renaming courses
rename_column(courses)
# Out:
# ['courses', 'school', 'school_id']
#
# Please enter the column you want to RENAME: ss
# Please enter the NEW NAME: s
# Do you want to CONTINUE?: no

# %%
#renaming badges
badges.columns
# Out:
# Index(['name', 'keyword', 'school', 'school_id'], dtype='object')

# %% [markdown]
# #### Dropping null values in primary keys

# %%
#clearing comments by comment_id
dropping_null(comments)
# Out:
# Index(['comment_id', 'anonymous', 'graduating_year', 'job_title', 'tagline',
#        'created_at', 'program', 'overall_score', 'overall', 'curriculum',
#        'job_support', 'school'],
#       dtype='object')
# Please enter the name of the collumn you want clearcomment_id
# 0

# %%
#clearing locations by campus_id
dropping_null(locations)
# Out:
# Index(['campus_id', 'country_id', 'country_name', 'country_abbrev', 'city_id',
#        'city_name', 'school', 'school_id'],
#       dtype='object')
# Please enter the name of the collumn you want clearcampus_id
# 0

# %%
reset_index(courses)
courses

# %% [markdown]
# #### Dropping duplicates in primary key

# %%
#comments 
sum(comments["comment_id"].duplicated())
# Out:
# 0

# %%
#locations
sum(locations["campus_id"].duplicated())
# Out:
# 0

# %%
sum(courses.duplicated())
# Out:
# 0

# %%
sum(badges.duplicated())
# Out:
# 0

# %% [markdown]
# #### lowering all the rows

# %%
comments.head(3)
# Out:
#    comment_id  anonymous  graduating_year                 job_title  \
# 0      306068       True           2023.0    Full stack development
# 1      305297      False           2023.0  Full Stack Web Developer
# 2      305278      False           2023.0          Product Designer
#
#                    tagline  created_at                   program  \
# 0          Now I can do it  10/31/2023                      None
# 1              It was good   10/2/2023  Web Development Bootcamp
# 2  Ironhack 100% Worth It!   9/30/2023     UX/UI Design Bootcamp
#
#   overall_score overall curriculum job_support    school
# 0           5.0     5.0        5.0         5.0  ironhack
# 1           4.0     5.0        3.0         4.0  ironhack
# 2           5.0     5.0        5.0         5.0  ironhack

# %%
locations.head(3)
# Out:
#    campus_id  country_id country_name country_abbrev  city_id    city_name  \
# 0      15901        57.0      Germany             DE  31156.0       Berlin
# 1      16022        29.0       Mexico             MX  31175.0  Mexico City
# 2      16086        59.0  Netherlands             NL  31168.0    Amsterdam
#
#      school  school_id
# 0  ironhack      10828
# 1  ironhack      10828
# 2  ironhack      10828

# %%
badges.head(3)
# Out:
#                 name            keyword    school  school_id
# 0   Available Online   available_online  ironhack      10828
# 1  Verified Outcomes  verified_outcomes  ironhack      10828
# 2   Flexible Classes   flexible_classes  ironhack      10828

# %%
courses.head(3)
# Out:
#                    courses    school  school_id
# 0  Cyber Security Bootcamp  ironhack      10828
# 1  Cybersecurity Part-Time  ironhack      10828
# 2  Data Analytics Bootcamp  ironhack      10828

# %% [markdown]
# #### Converting graduating_year (comments table) into integer

# %%
comments.dropna(subset = "graduating_year", inplace = True)

# %%
def set_integer(row):
        return int(row)

# %%
comments["graduating_year"] = comments["graduating_year"].apply(set_integer)

# %%
comments.head(1)
# Out:
#    comment_id  anonymous  graduating_year               job_title  \
# 0      306068       True             2023  Full stack development
#
#            tagline  created_at program overall_score overall curriculum  \
# 0  Now I can do it  10/31/2023    None           5.0     5.0        5.0
#
#   job_support    school
# 0         5.0  ironhack

# %% [markdown]
# ## Exporting into csv file

# %%
comments_cleaned = comments.copy()
campuses_cleaned = locations.copy()
bagdes_cleaned = badges.copy()
courses_cleaned = courses.copy()

# %%
comments_cleaned.to_csv('output.csv')
